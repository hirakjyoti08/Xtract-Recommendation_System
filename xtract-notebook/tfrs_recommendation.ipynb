# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_recommenders as tfrs
from tensorflow.keras import layers
import ast
from collections import Counter

# %%
df = pd.read_csv("E:/NITD/ML_Project/xtract-api/DataSet/arxiv_processed.csv")
df.head()
# Out:
#                  id                                              title  \
# 0  acc-phys/9607001  An Investigation of Stochastic Cooling in the ...
# 1  acc-phys/9601001  Particle Motion in the Stable Region Near an E...
# 2  acc-phys/9602001                                     Muon Colliders
# 3  adap-org/9306005  Prediction and Adaptation in an Evolving Chaot...
# 4  chao-dyn/9407001  Pattern Dynamics of a Coupled Map Lattice for ...
#
#                                             abstract  \
# 0    This report provides a description of unbunc...
# 1    This paper studies the particle motion when ...
# 2    Muon Colliders have unique technical and phy...
# 3    We describe the results of analytic calculat...
# 4    The pattern dynamics of the one-way coupled ...
#
#                                              authors  \
# 0                                         O. Meincke
# 1         G. Parzen (Brookhaven National Laboratory)
# 2  R. B. Palmer(BNL), A. Sessler(LBNL), A. Skrins...
# 3  Alfred H\"ubler and David Pines (Santa Fe Inst...
# 4  Frederick H. Willeboordse (University of Tokyo...
#
#                                        category_code update_date  \
# 0                            acc-phys physics.acc-ph  2008-02-03
# 1                            acc-phys physics.acc-ph  2008-02-03
# 2                            acc-phys physics.acc-ph  2012-08-29
# 3                  adap-org chao-dyn nlin.AO nlin.CD  2008-02-03
# 4  chao-dyn adap-org nlin.AO nlin.CD nlin.PS patt...  2015-06-24
#
#                                          clean_title  \
# 0  an investigation of stochastic cooling in the ...
# 1  particle motion in the stable region near an e...
# 2                                     muon colliders
# 3  prediction and adaptation in an evolving chaot...
# 4  pattern dynamics of a coupled map lattice for ...
#
#                                       clean_abstract  \
# 0  this report provides a description of unbunche...
# 1  this paper studies the particle motion when th...
# 2  muon colliders have unique technical and physi...
# 3  we describe the results of analytic calculatio...
# 4  the pattern dynamics of the one way coupled lo...
#
#                                             category
# 0  Accelerator Physics, Physics – Accelerator Phy...
# 1  Accelerator Physics, Physics – Accelerator Phy...
# 2  Accelerator Physics, Physics – Accelerator Phy...
# 3  Adaptation, Noise, and Self-Organizing Systems...
# 4  Adaptation, Noise, and Self-Organizing Systems...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194065 entries, 0 to 194064
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              194065 non-null  object
#  1   title           194065 non-null  object
#  2   abstract        194065 non-null  object
#  3   authors         194065 non-null  object
#  4   category_code   194065 non-null  object
#  5   update_date     194065 non-null  object
#  6   clean_title     194065 non-null  object
#  7   clean_abstract  194065 non-null  object
#  8   category        194065 non-null  object
#  9   text            194065 non-null  object
# dtypes: object(10)
# memory usage: 14.8+ MB

# %%
df['clean_title'] = df['clean_title'].fillna('').astype(str)
df['clean_abstract'] = df['clean_abstract'].fillna('').astype(str)
df['title'] = df['title'].fillna('').astype(str)

df['text'] = df['clean_title'] + " " + df['clean_abstract']
df.head()
# Out:
#                  id                                              title  \
# 0  acc-phys/9607001  An Investigation of Stochastic Cooling in the ...
# 1  acc-phys/9601001  Particle Motion in the Stable Region Near an E...
# 2  acc-phys/9602001                                     Muon Colliders
# 3  adap-org/9306005  Prediction and Adaptation in an Evolving Chaot...
# 4  chao-dyn/9407001  Pattern Dynamics of a Coupled Map Lattice for ...
#
#                                             abstract  \
# 0    This report provides a description of unbunc...
# 1    This paper studies the particle motion when ...
# 2    Muon Colliders have unique technical and phy...
# 3    We describe the results of analytic calculat...
# 4    The pattern dynamics of the one-way coupled ...
#
#                                              authors  \
# 0                                         O. Meincke
# 1         G. Parzen (Brookhaven National Laboratory)
# 2  R. B. Palmer(BNL), A. Sessler(LBNL), A. Skrins...
# 3  Alfred H\"ubler and David Pines (Santa Fe Inst...
# 4  Frederick H. Willeboordse (University of Tokyo...
#
#                                        category_code update_date  \
# 0                            acc-phys physics.acc-ph  2008-02-03
# 1                            acc-phys physics.acc-ph  2008-02-03
# 2                            acc-phys physics.acc-ph  2012-08-29
# 3                  adap-org chao-dyn nlin.AO nlin.CD  2008-02-03
# 4  chao-dyn adap-org nlin.AO nlin.CD nlin.PS patt...  2015-06-24
#
#                                          clean_title  \
# 0  an investigation of stochastic cooling in the ...
# 1  particle motion in the stable region near an e...
# 2                                     muon colliders
# 3  prediction and adaptation in an evolving chaot...
# 4  pattern dynamics of a coupled map lattice for ...
#
#                                       clean_abstract  \
# 0  this report provides a description of unbunche...
# 1  this paper studies the particle motion when th...
# 2  muon colliders have unique technical and physi...
# 3  we describe the results of analytic calculatio...
# 4  the pattern dynamics of the one way coupled lo...
#
#                                             category  \
# 0  Accelerator Physics, Physics – Accelerator Phy...
# 1  Accelerator Physics, Physics – Accelerator Phy...
# 2  Accelerator Physics, Physics – Accelerator Phy...
# 3  Adaptation, Noise, and Self-Organizing Systems...
# 4  Adaptation, Noise, and Self-Organizing Systems...
#
#                                                 text
# 0  an investigation of stochastic cooling in the ...
# 1  particle motion in the stable region near an e...
# 2  muon colliders muon colliders have unique tech...
# 3  prediction and adaptation in an evolving chaot...
# 4  pattern dynamics of a coupled map lattice for ...

# %%
df['text'] = df['text'].apply(lambda x: str(x))
df['title'] = df['title'].apply(lambda x: str(x))

# %%
data = tf.data.Dataset.from_tensor_slices({
    "text": df['text'].values,
    "title": df['title'].values
})

data = data.shuffle(10000).batch(128)

# %%
max_tokens = 8500
embedding_dim = 64
vectorize_layer = layers.TextVectorization(max_tokens=max_tokens, output_sequence_length=270)
vectorize_layer.adapt(df['text'].values)

def build_text_encoder():
    return tf.keras.Sequential([
        vectorize_layer,
        layers.Embedding(max_tokens, embedding_dim),
        layers.GlobalAveragePooling1D(),
        layers.Dense(64)
    ])

# %%
class PaperModel(tfrs.Model):
    def __init__(self):
        super().__init__()
        self.query_model = build_text_encoder()
        self.candidate_model = build_text_encoder()

        self.task = tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates=data.map(lambda x: x["text"])
            )
        )

    def compute_loss(self, features, training=False):
        query_embeddings = self.query_model(features["text"])
        candidate_embeddings = self.candidate_model(features["text"])
        return self.task(query_embeddings, candidate_embeddings)

# %%
model = PaperModel()
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.1))
model.fit(data, epochs=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 model = PaperModel()
#       2 model.compile(optimizer=tf.keras.optimizers.Adagrad(0.1))
#       3 model.fit(data, epochs=3)
#
# Cell In[56], line 8, in PaperModel.__init__(self)
#       4 self.query_model = build_text_encoder()
#       5 self.candidate_model = build_text_encoder()
#       7 self.task = tfrs.tasks.Retrieval(
# ----> 8     metrics=tfrs.metrics.FactorizedTopK(
#       9         candidates=data.map(lambda x: x["text"])
#      10     )
#      11 )
#
# File e:\NITD\ML_Project\.venv\Lib\site-packages\tensorflow_recommenders\metrics\factorized_top_k.py:79, in FactorizedTopK.__init__(self, candidates, ks, name)
#      75 super().__init__(name=name)
#      77 if isinstance(candidates, tf.data.Dataset):
#      78   candidates = (
# ---> 79       layers.factorized_top_k.Streaming(k=max(ks))
#      80       .index_from_dataset(candidates)
#      81   )
#      83 self._ks = ks
#      84 self._candidates = candidates
#
# File e:\NITD\ML_Project\.venv\Lib\site-packages\tensorflow_recommenders\layers\factorized_top_k.py:376, in Streaming.__init__(self, query_model, k, handle_incomplete_batches, num_parallel_calls, sorted_order)
#     373 self._num_parallel_calls = num_parallel_calls
#     374 self._sorted = sorted_order
# --> 376 self._counter = self.add_weight("counter", dtype=tf.int32, trainable=False)
#
# File e:\NITD\ML_Project\.venv\Lib\site-packages\keras\src\layers\layer.py:575, in Layer.add_weight(self, shape, initializer, dtype, trainable, autocast, regularizer, constraint, aggregation, overwrite_with_gradient, name)
#     573 initializer = initializers.get(initializer)
#     574 with backend.name_scope(self.name, caller=self):
# --> 575     variable = backend.Variable(
#     576         initializer=initializer,
#     577         shape=shape,
#     578         dtype=dtype,
#     579         trainable=trainable,
#     580         autocast=autocast,
#     581         aggregation=aggregation,
#     582         name=name,
#     583     )
#     584 # Will be added to layer.losses
#     585 variable.regularizer = regularizers.get(regularizer)
#
# File e:\NITD\ML_Project\.venv\Lib\site-packages\keras\src\backend\common\variables.py:205, in Variable.__init__(***failed resolving arguments***)
#     203 else:
#     204     if callable(initializer):
# --> 205         self._shape = self._validate_shape(shape)
#     206         self._initialize_with_initializer(initializer)
#     207     else:
#
# File e:\NITD\ML_Project\.venv\Lib\site-packages\keras\src\backend\common\variables.py:232, in Variable._validate_shape(self, shape)
#     231 def _validate_shape(self, shape):
# --> 232     shape = standardize_shape(shape)
#     233     if None in shape:
#     234         raise ValueError(
#     235             "Shapes used to initialize variables must be "
#     236             "fully-defined (no `None` dimensions). Received: "
#     237             f"shape={shape} for variable path='{self.path}'"
#     238         )
#
# File e:\NITD\ML_Project\.venv\Lib\site-packages\keras\src\backend\common\variables.py:617, in standardize_shape(shape)
#     615     continue
#     616 if not is_int_dtype(type(e)):
# --> 617     raise ValueError(
#     618         f"Cannot convert '{shape}' to a shape. "
#     619         f"Found invalid entry '{e}' of type '{type(e)}'. "
#     620     )
#     621 if e < 0:
#     622     raise ValueError(
#     623         f"Cannot convert '{shape}' to a shape. "
#     624         "Negative dimensions are not allowed."
#     625     )
#
# ValueError: Cannot convert '('c', 'o', 'u', 'n', 't', 'e', 'r')' to a shape. Found invalid entry 'c' of type '<class 'str'>'.
